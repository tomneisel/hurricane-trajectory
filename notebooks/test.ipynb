# %%
import pandas as pd

from hurricane_ml.visualization import plot_hurricane

# %%
data = pd.read_csv("../data/ibtracs.NA.list.v04r01.csv", skiprows=[1])
# Out:
# /tmp/ipykernel_20287/4173865976.py:1: DtypeWarning: Columns (3,19,20,23,24,40,172,173) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("../data/ibtracs.NA.list.v04r01.csv", skiprows=[1])

# %%
hurricane_df = data.drop(data[data["SEASON"] < 1980].index)

# %%
hurricane_df
# Out:
#                   SID  SEASON  NUMBER BASIN SUBBASIN     NAME  \
# 85538   1980199N31284    1980      47   NaN      NaN  UNNAMED
# 85539   1980199N31284    1980      47   NaN      NaN  UNNAMED
# 85540   1980199N31284    1980      47   NaN      NaN  UNNAMED
# 85541   1980199N31284    1980      47   NaN      NaN  UNNAMED
# 85542   1980199N31284    1980      47   NaN      NaN  UNNAMED
# ...               ...     ...     ...   ...      ...      ...
# 127240  2026241N30273    2026      61   NaN      NaN  EDOUARD
# 127241  2026241N30273    2026      61   NaN      NaN  EDOUARD
# 127242  2026241N30273    2026      61   NaN      NaN  EDOUARD
# 127243  2026241N30273    2026      61   NaN      NaN  EDOUARD
# 127244  2026241N30273    2026      61   NaN      NaN  EDOUARD
#
#                    ISO_TIME NATURE   LAT   LON  ... BOM_GUST_PER REUNION_GUST  \
# 85538   1980-07-17 00:00:00     TS  30.5 -76.5  ...
# 85539   1980-07-17 03:00:00     TS  30.3 -76.9  ...
# ...

# %%
katrina = hurricane_df[hurricane_df["SID"] == "2005236N23285"]

plot_hurricane(katrina, "Hurricane Katrina (2005)")
